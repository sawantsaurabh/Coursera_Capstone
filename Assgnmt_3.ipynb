# %% [markdown]
# Code to extract data from wiki

# %%
import requests
website_url=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
from bs4 import BeautifulSoup
import pandas as pd
soup = BeautifulSoup(website_url,'lxml')

# %% [markdown]
# Extracting table and storing it into dataframe

# %%
postcode=[]
borough=[]
neighbourhood=[]
for items in soup.find('table', class_='wikitable sortable').find_all('tr')[1::1]:
    data = items.find_all(['th','td'])
    try:
        postcode.append(data[0].text)        
        borough.append(data[1].text)
        neighbourhood.append(data[2].text)
    except IndexError:pass
#    print("{}|{}|{}".format(country,title,name))

postal_code_canada = pd.DataFrame(
    {'Postcode': postcode,
     'Borough': borough,
     'Neighbourhood': neighbourhood
    })
# Out:
# (289, 3)

# %% [markdown]
# Aggregating data on the basis of "Neighbourhood"

# %%
postal_code_canada_1=pd.DataFrame(postal_code_canada.groupby(['Postcode','Borough']).Neighbourhood.agg([('Neighbourhood', ', '.join)])).reset_index()

# %% [markdown]
# Replacing "Neighbourhood" column data with "Borough" where "Neighbourhood"== "Not assigned\n"

# %%
for idx,row in postal_code_canada_1.iterrows():
    if  postal_code_canada_1.loc[idx,'Neighbourhood'] == 'Not assigned\n':
        postal_code_canada_1.loc[idx,'Neighbourhood'] = postal_code_canada_1.loc[idx,'Borough']

# %%
postal_code_canada_1.shape
#postal_code_canada_1.loc[postal_code_canada_1['Postcode'] == 'M7A']
#postal_code_canada_1.loc[postal_code_canada_1['Neighbourhood'] = 'Not assigned\n']
# Out:
#     Postcode       Borough Neighbourhood
# 120      M7A  Queen's Park  Queen's Park

# %%
# Out:
# Not assigned Not assigned
#
# Scarborough Rouge
# , Malvern
#
# Scarborough Highland Creek
# , Rouge Hill
# , Port Union
#
# Scarborough Guildwood
# , Morningside
# , West Hill
#
# Scarborough Woburn
#
# Scarborough Cedarbrae
#
# Scarborough Scarborough Village
#
# Scarborough East Birchmount Park
# , Ionview
# , Kennedy Park
#
# Scarborough Clairlea
# , Golden Mile
# , Oakridge
#
# Scarborough Cliffcrest
# , Cliffside
# , Scarborough Village West
#
# Scarborough Birch Cliff
# , Cliffside West
#
# Scarborough Dorset Park
# , Scarborough Town Centre
# , Wexford Heights
#
# Scarborough Maryvale
# , Wexford
#
# Scarborough Agincourt
#
# Scarborough Clarks Corners
# , Sullivan
# , Tam O'Shanter
#
# Scarborough Agincourt North
# , L'Amoreaux East
# , Milliken
# , Steeles East
#
# Scarborough L'Amoreaux West
# , Steeles West
#
# Scarborough Upper Rouge
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# North York Hillcrest Village
#
# North York Fairview
# , Henry Farm
# , Oriole
#
# North York Bayview Village
#
# North York Silver Hills
# , York Mills
#
# North York Newtonbrook
# , Willowdale
#
# North York Willowdale South
#
# North York York Mills West
#
# North York Willowdale West
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# North York Parkwoods
#
# North York Don Mills North
#
# North York Flemingdon Park
# , Don Mills South
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# North York Bathurst Manor
# , Downsview North
# , Wilson Heights
#
# North York Northwood Park
# , York University
#
# North York CFB Toronto
# , Downsview East
#
# North York Downsview West
#
# North York Downsview Central
#
# North York Downsview Northwest
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# North York Victoria Village
#
# East York Woodbine Gardens
# , Parkview Hill
#
# East York Woodbine Heights
#
# East Toronto The Beaches
#
# East York Leaside
#
# East York Thorncliffe Park
#
# East York East Toronto
#
# East Toronto The Danforth West
# , Riverdale
#
# East Toronto The Beaches West
# , India Bazaar
#
# East Toronto Studio District
#
# Central Toronto Lawrence Park
#
# Central Toronto Davisville North
#
# Central Toronto North Toronto West
#
# Central Toronto Davisville
#
# Central Toronto Moore Park
# , Summerhill East
#
# Central Toronto Deer Park
# , Forest Hill SE
# , Rathnelly
# , South Hill
# , Summerhill West
#
# Downtown Toronto Rosedale
#
# Downtown Toronto Cabbagetown
# , St. James Town
#
# Downtown Toronto Church and Wellesley
#
# Not assigned Not assigned
#
# Downtown Toronto Harbourfront
# , Regent Park
#
# Downtown Toronto Ryerson
# , Garden District
#
# Downtown Toronto St. James Town
#
# Downtown Toronto Berczy Park
#
# Downtown Toronto Central Bay Street
#
# Downtown Toronto Adelaide
# , King
# , Richmond
#
# Downtown Toronto Harbourfront East
# , Toronto Islands
# , Union Station
#
# Downtown Toronto Design Exchange
# , Toronto Dominion Centre
#
# Downtown Toronto Commerce Court
# , Victoria Hotel
#
# North York Bedford Park
# , Lawrence Manor East
#
# Central Toronto Roselawn
#
# Central Toronto Forest Hill North
# , Forest Hill West
#
# Central Toronto The Annex
# , North Midtown
# , Yorkville
#
# Downtown Toronto Harbord
# , University of Toronto
#
# Downtown Toronto Chinatown
# , Grange Park
# , Kensington Market
#
# Downtown Toronto CN Tower
# , Bathurst Quay
# , Island airport
# , Harbourfront West
# , King and Spadina
# , Railway Lands
# , South Niagara
#
# Downtown Toronto Stn A PO Boxes 25 The Esplanade
#
# Downtown Toronto First Canadian Place
# , Underground city
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# North York Lawrence Heights
# , Lawrence Manor
#
# North York Glencairn
#
# York Humewood-Cedarvale
#
# York Caledonia-Fairbanks
#
# Downtown Toronto Christie
#
# West Toronto Dovercourt Village
# , Dufferin
#
# West Toronto Little Portugal
# , Trinity
#
# West Toronto Brockton
# , Exhibition Place
# , Parkdale Village
#
# North York Maple Leaf Park
# , North Park
# , Upwood Park
#
# York Del Ray
# , Keelesdale
# , Mount Dennis
# , Silverthorn
#
# York The Junction North
# , Runnymede
#
# West Toronto High Park
# , The Junction South
#
# West Toronto Parkdale
# , Roncesvalles
#
# West Toronto Runnymede
# , Swansea
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Queen's Park Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Mississauga Canada Post Gateway Processing Centre
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# East Toronto Business reply mail Processing Centre969 Eastern
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Etobicoke Humber Bay Shores
# , Mimico South
# , New Toronto
#
# Etobicoke Alderwood
# , Long Branch
#
# Etobicoke The Kingsway
# , Montgomery Road
# , Old Mill North
#
# Etobicoke Humber Bay
# , King's Mill Park
# , Kingsway Park South East
# , Mimico NE
# , Old Mill South
# , The Queensway East
# , Royal York South East
# , Sunnylea
#
# Etobicoke Kingsway Park South West
# , Mimico NW
# , The Queensway West
# , Royal York South West
# , South of Bloor
#
# Etobicoke Islington Avenue
#
# Etobicoke Cloverdale
# , Islington
# , Martin Grove
# , Princess Gardens
# , West Deane Park
#
# Etobicoke Bloordale Gardens
# , Eringate
# , Markland Wood
# , Old Burnhamthorpe
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# North York Humber Summit
#
# North York Emery
# , Humberlea
#
# York Weston
#
# Etobicoke Westmount
#
# Etobicoke Kingsview Village
# , Martin Grove Gardens
# , Richview Gardens
# , St. Phillips
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Etobicoke Albion Gardens
# , Beaumond Heights
# , Humbergate
# , Jamestown
# , Mount Olive
# , Silverstone
# , South Steeles
# , Thistletown
#
# Etobicoke Northwest
#
# Not assigned Not assigned
#
# Not assigned Not assigned
#
# Not assigned Not assigned
